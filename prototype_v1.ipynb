# %% [markdown]
# # Rec Sys of Answerers for StackOverflow
# ## Version 1.0

# %% [markdown]
# Loading Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from collections import defaultdict
from scipy.sparse import csr_matrix
from scipy.sparse.linalg import norm
from sklearn.model_selection import train_test_split
import ast

# %% [markdown]
# Loading Data

# %%
df_question = pd.read_csv("dataset/questions_2019.csv")
df_answer = pd.read_csv("dataset/answers_2019.csv")

# %%
df_question.head()
# Out:
#    QuestionId  QuestionOwnerId  \
# 0    54936100          3419772
# 1    54936106          3997132
# 2    54936108          4992551
# 3    54936109          2239552
# 4    54936112          5505171
#
#                                        QuestionTitle  \
# 0      R 3.5.2: Error in loading stock data from zoo
# 1        Different behaviour of range with lodash/fp
# 2  webPack dev server proxy rewrite URLs in response
# 3                          EF Core 2.0 Global Filter
# 4  Clustered column chart in C# using Chart in Wi...
#
#                                    QuestionTags  QuestionVotes  \
# 0                                         ['r']              0
# 1          ['functional-programming', 'lodash']              1
# 2             ['webpack', 'webpack-dev-server']              2
# 3                                        ['c#']              0
# 4  ['c#', 'winforms', 'charts', 'column-chart']              0
#
#   QuestionCreationDate  AnswerCount
# 0  2019-03-01 00:00:10            1
# 1  2019-03-01 00:01:48            1
# 2  2019-03-01 00:01:55            1
# 3  2019-03-01 00:02:36            0
# 4  2019-03-01 00:02:47            0

# %%
df_answer.head()
# Out:
#    QuestionId  AnswerOwnerId  AnswerVotes   AnswerCreationDate
# 0    56140111       10245958            3  2019-05-15 00:07:23
# 1    56140157        1226963            0  2019-05-15 00:12:34
# 2    56140125        6841773            0  2019-05-15 00:12:44
# 3    56140150        1440565            5  2019-05-15 00:12:52
# 4    56140150       11015427           15  2019-05-15 00:16:46

# %% [markdown]
# Transfoming list of tags

# %%
df_question['QuestionTags'] = df_question['QuestionTags'].apply(ast.literal_eval)

# %%
df_question
# Out:
#         QuestionId  QuestionOwnerId  \
# 0         54936100          3419772
# 1         54936106          3997132
# 2         54936108          4992551
# 3         54936109          2239552
# 4         54936112          5505171
# ...            ...              ...
# 878713    54272409         10245420
# 878714    54272411          8906835
# 878715    54272412         10893334
# 878716    54272414         10564619
# 878717    54272418         10934024
#
#                                             QuestionTitle  \
# 0           R 3.5.2: Error in loading stock data from zoo
# 1             Different behaviour of range with lodash/fp
# 2       webPack dev server proxy rewrite URLs in response
# 3                               EF Core 2.0 Global Filter
# 4       Clustered column chart in C# using Chart in Wi...
# ...                                                   ...
# 878713                Selenium iframe Data issue - python
# 878714     Problem on adding Bootstrap carousel component
# 878715  NativeScript Vue nativescript-sqlite cannot as...
# 878716  How to fix 'TypeError' that comes up for some ...
# 878717  Getting only a repeating files from directory ...
#
#                                           QuestionTags  QuestionVotes  \
# 0                                                  [r]              0
# 1                     [functional-programming, lodash]              1
# 2                        [webpack, webpack-dev-server]              2
# 3                                                 [c#]              0
# 4                 [c#, winforms, charts, column-chart]              0
# ...                                                ...            ...
# 878713  [python, selenium, selenium-webdriver, iframe]              1
# 878714               [bootstrap-4, bootstrap-carousel]              0
# 878715        [sqlite, nativescript, nativescript-vue]              0
# 878716                             [python, typeerror]              1
# 878717        [powershell, csv, unique, get-childitem]              1
#
#        QuestionCreationDate  AnswerCount
# 0       2019-03-01 00:00:10            1
# 1       2019-03-01 00:01:48            1
# 2       2019-03-01 00:01:55            1
# 3       2019-03-01 00:02:36            0
# 4       2019-03-01 00:02:47            0
# ...                     ...          ...
# 878713  2019-01-19 23:57:14            1
# 878714  2019-01-19 23:57:26            1
# 878715  2019-01-19 23:57:36            1
# 878716  2019-01-19 23:57:54            1
# 878717  2019-01-19 23:59:27            1
#
# [878718 rows x 7 columns]

# %% [markdown]
# ## Prototype 1
#
# - **Goal:** Find answerers to new posted question.
#
# - **Approach:** Collaborative Filtering (Item Based) --> Utilize question tags of previous answered questions, to indicate the most appropriate user.
#
# - **Steps:**
#
# 1. Create Matrix of User-Tags

# %% [markdown]
# ### Dividing the question dataset into Train and Test

# %%
train_data, test_data = train_test_split(df_question, test_size=0.1, random_state=42)

# %% [markdown]
# Merging QuestionTags to UserAnswerId

# %%
df_merged = train_data[["QuestionId","QuestionTags"]].merge(df_answer[["QuestionId", "AnswerOwnerId"]], how='inner', on = "QuestionId", )

# %% [markdown]
# Getting all tags of a user -> for checking purposes

# %%
df_grouped_tags = (
    df_merged.groupby("AnswerOwnerId")["QuestionTags"]
    .apply(lambda tags: list(set(tag for sublist in tags for tag in sublist)))  # Flatten and deduplicate tags
    .reset_index()
)

df_grouped_tags.columns = ["AnswerOwnerId", "CombinedTags"]

# %%
df_grouped_tags[df_grouped_tags["AnswerOwnerId"] == 10221765]["CombinedTags"].iloc[0]
# Out:
# ['big-o',
#  'date',
#  'polymer-3.x',
#  'json',
#  'firebase-authentication',
#  'submit',
#  'syntax',
#  'logical-operators',
#  'api',
#  'angularjs',
#  'node-kafka',
#  'nested',
#  'dry',
#  'electron',
#  'digits',
#  'menu',
#  'conditional-statements',
#  'return',
#  'es6-modules',
#  'fizzbuzz',
#  'decorator',
#  'eslint',
#  'hoisting',
#  'screen-rotation',
#  'indexof',
#  'autocomplete',
#  'ecmascript-2018',
#  'iframe',
#  'indexing',
#  'for-loop',
#  'key',
#  'frontend',
#  'styles',
#  'this',
#  'href',
#  'primefaces',
#  'express',
#  'dom-events',
#  'compiler-optimization',
#  'semantic-ui',
#  'p5.js',
#  'document-ready',
#  'parseint',
#  'console',
#  'replace',
#  'prompt',
#  'es6-class',
#  'variable-declaration',
#  'html',
#  'nodemailer',
#  'html-table',
#  'switch-statement',
#  'logic',
#  'drop-down-menu',
#  'finally',
#  'csv',
#  'grouping',
#  'arrays',
#  'array.prototype.map',
#  'sql',
#  'output',
#  'google-cloud-spanner',
#  'node.js',
#  'jsx',
#  'babel-jest',
#  'template-literals',
#  'mustache',
#  'google-cloud-firestore',
#  'destructuring',
#  'react-redux',
#  'asp.net',
#  'fs',
#  'speech-recognition',
#  'throw',
#  'datatables',
#  'long-integer',
#  'algorithm',
#  'nodejs-server',
#  'boolean',
#  'email-validation',
#  'parent-child',
#  'carousel',
#  'vuetify.js',
#  'dart',
#  'caesar-cipher',
#  'php',
#  'assignment-operator',
#  'mongo-shell',
#  'functional-programming',
#  'forms',
#  'google-chrome-devtools',
#  'vue-component',
#  'orm',
#  'xml',
#  'coordinates',
#  'dynamic',
#  'hex',
#  'numpy',
#  'async-await',
#  'sublimetext',
#  'ecmascript-2016',
#  'developer-tools',
#  'momentjs',
#  'typescript',
#  'chai',
#  'set',
#  'global',
#  'navigator',
#  'reactjs',
#  'if-statement',
#  'video',
#  'canvas',
#  'font-awesome',
#  'break',
#  'syntax-error',
#  'duplicates',
#  'clojurescript',
#  'extendscript',
#  'unique',
#  'bootstrap-4',
#  'alexa-skills-kit',
#  'webpack',
#  'associative-array',
#  'react-native',
#  'higher-order-functions',
#  'vuejs2',
#  'less',
#  'youtube-api',
#  'var',
#  'immutable.js',
#  'parameter-passing',
#  'attributes',
#  'polyfills',
#  'master-pages',
#  'extract',
#  'firefox',
#  'sublimetext3',
#  'require',
#  'object-destructuring',
#  'urlencode',
#  'websocket',
#  'numbers',
#  'web',
#  'vba',
#  'push',
#  'filesystems',
#  'removechild',
#  'collections',
#  'requirejs',
#  'asynchronous',
#  'loops',
#  'scope',
#  'google-cloud-functions',
#  'random',
#  'reduce',
#  'kafka-consumer-api',
#  'button',
#  'inline',
#  'immutability',
#  'angular',
#  'flatmap',
#  'xmlhttprequest',
#  'comparison',
#  'array-push',
#  'javascript-objects',
#  'axios',
#  'export',
#  'jestjs',
#  'css-selectors',
#  'discord',
#  'mode',
#  'append',
#  'orientation',
#  'w3.css',
#  'external-js',
#  'lodash',
#  'case-sensitive',
#  'concatenation',
#  'iteration',
#  'local-storage',
#  'closures',
#  'setinterval',
#  'bookmarklet',
#  'shopify',
#  'multiplication',
#  'xpath',
#  'alert',
#  'array-filter',
#  'types',
#  'es6-promise',
#  'addition',
#  'color-picker',
#  'callback',
#  'keyboard-events',
#  'indexeddb',
#  'methods',
#  'encryption',
#  'try-catch',
#  'time-complexity',
#  'swift',
#  'firebase',
#  'performance',
#  'clipboard.js',
#  'spread-syntax',
#  'mongodb-query',
#  'internet-explorer-11',
#  'keyvaluepair',
#  'window',
#  'firebase-realtime-database',
#  'defineproperty',
#  'cheerio',
#  'object',
#  'mongoose',
#  'null',
#  'css',
#  'preventdefault',
#  'prototype',
#  'undefined',
#  'clock',
#  'html-lists',
#  'mysql',
#  'twemoji',
#  'html5-history',
#  'strict',
#  'slice',
#  'ternary-operator',
#  'module',
#  'c#',
#  'web-console',
#  'vuex',
#  'putimagedata',
#  'python',
#  'laravel',
#  'parsing',
#  'class',
#  'email',
#  'pug',
#  'dom',
#  'map-function',
#  'split',
#  'javascript',
#  'regex-group',
#  'jsf',
#  'import',
#  'puppeteer',
#  'properties',
#  'ionic4',
#  'hasownproperty',
#  'parameters',
#  'emoji',
#  'handlebars.js',
#  'currying',
#  'settimeout',
#  'nodelist',
#  'jquery',
#  'text',
#  'ionic-framework',
#  'tree',
#  'calculator',
#  'web-component',
#  'input',
#  'expo',
#  'console.log',
#  'ajax',
#  'numpy-ndarray',
#  'google-chrome',
#  'foreach',
#  'django',
#  'ejs',
#  'ecmascript-5',
#  'eval',
#  'tabs',
#  'socket.io',
#  'ecmascript-6',
#  'npm',
#  'key-value-store',
#  'modulo',
#  'mongodb',
#  'function',
#  'angular-directive',
#  'internet-explorer',
#  'unicode',
#  'multidimensional-array',
#  'variables',
#  'alphabetical',
#  'session',
#  'underscore.js',
#  'rest',
#  'math',
#  'escaping',
#  'toggle',
#  'global-variables',
#  'substring',
#  'discord.js',
#  'circular-dependency',
#  'sorting',
#  'regex',
#  'get',
#  'ramda.js',
#  'reload',
#  'factory',
#  'constructor',
#  'inheritance',
#  'http-redirect',
#  'arguments',
#  'onscroll',
#  'rgb',
#  'vuelidate',
#  'jasmine',
#  'overwrite',
#  'recursion',
#  'dojo',
#  'hashmap',
#  'addeventlistener',
#  'external',
#  'html-select',
#  'd3.js',
#  'static',
#  'cookies',
#  'reverse',
#  'separator',
#  'redux',
#  'browser',
#  'vue.js',
#  'fibonacci',
#  'arrow-functions',
#  'go',
#  'filter',
#  'string',
#  'eventsource',
#  'promise',
#  'find',
#  'excel',
#  'ecmascript-2017']

# %%
1943329

# %% [markdown]
# ### Indexing tags and users

# %%
dic_merged = df_merged.to_dict(orient="records")

# %%
unique_tags = list({tag for question in dic_merged for tag in question['QuestionTags']})
unique_users = list({question['AnswerOwnerId'] for question in dic_merged})

tag_to_index = {tag: idx for idx, tag in enumerate(unique_tags)}
user_to_index = {user: idx for idx, user in enumerate(unique_users)}

# %% [markdown]
# ### Creating User-Tag Matrix

# %%
# Step 2: Create a Sparse User-Tag Matrix
rows, cols, data = [], [], []
for question in dic_merged:
    user_idx = user_to_index[question['AnswerOwnerId']]
    for tag in question['QuestionTags']:
        tag_idx = tag_to_index[tag]
        rows.append(user_idx)
        cols.append(tag_idx)
        data.append(1)

# Create a sparse matrix 
user_tag_matrix_sparse = csr_matrix((data, (rows, cols)), shape=(len(unique_users), len(unique_tags)))

# %% [markdown]
# ### Calculating Tags Similarity Matrix

# %%
# Compute Tag Similarity
cos_sim_matrix = cosine_similarity(user_tag_matrix_sparse.T)

# %% [markdown]
# ### Recommending User

# %%
test_data
# Out:
#         QuestionId  QuestionOwnerId  \
# 275130    56705914         11659955
# 623441    55720363          2579263
# 603387    55655622         11199969
# 351087    56204717         11519243
# 44361     55080751         11176740
# ...            ...              ...
# 655321    54666432          1090791
# 673240    54725077          9972840
# 212070    55915405         11183751
# 185854    56393739         11548820
# 632059    55748379          9696976
#
#                                             QuestionTitle  \
# 275130  How to style my react select when it is disabl...
# 623441  Serializing into dictionary Stored Procedure r...
# 603387                   Refresh page from another (page)
# 351087  Slow loading web page served by Node.js HTTP s...
# 44361          Castle Windsor 5.0 PerWebRequest Lifestyle
# ...                                                   ...
# 655321  What does interface annotated with jsr305 Thre...
# 673240  How to add a color gradient to a radar plot ba...
# 212070                             Convert to nginx rules
# 185854      write function not working properly in python
# 632059  Use annotate("rect") for one facet in ggplot w...
#
#                                              QuestionTags  QuestionVotes  \
# 275130                   [javascript, html, css, reactjs]              0
# 623441  [python, stored-procedures, flask, sqlalchemy,...              0
# 603387              [javascript, php, jquery, html, ajax]              3
# 351087                    [node.js, video.js, httpserver]              1
# 44361                                           [asp.net]              2
# ...                                                   ...            ...
# 655321                                     [java, jsr305]             -1
# 673240                     [r, radar-chart, spider-chart]              1
# 212070                             [nginx, url-rewriting]              1
# 185854                               [python, python-3.x]              0
# 632059                      [r, ggplot2, facet, annotate]              5
#
#        QuestionCreationDate  AnswerCount
# 275130  2019-06-21 15:00:47            1
# 623441  2019-04-17 05:17:42            1
# 603387  2019-04-12 16:05:10            2
# 351087  2019-05-19 04:18:20            1
# 44361   2019-03-09 18:39:45            1
# ...                     ...          ...
# 655321  2019-02-13 09:16:44            2
# 673240  2019-02-16 16:16:22            0
# 212070  2019-04-30 06:52:46            0
# 185854  2019-05-31 10:52:55            2
# 632059  2019-04-18 14:38:31            1
#
# [87872 rows x 7 columns]

# %%
## Example to 1 question
tags = test_data["QuestionTags"].iloc[0]
tags
# Out:
# ['javascript', 'html', 'css', 'reactjs']

# %%
def recommend_users(tags, top_n=10):
    # Get indices of the tags
    tag_indices = [tag_to_index[tag] for tag in tags if tag in tag_to_index]
    if len(tag_indices)==0:
        return [] ## No tag found to make the suggestion
    
    # Combine similarities for the requested tags
    similarity_tags = [cos_sim_matrix[:, tag_index] for tag_index in tag_indices]
    combined_similarity = sum(similarity_tags)

    # Compute user scores 
    user_scores_vector = user_tag_matrix_sparse.dot(combined_similarity)

    # Map scores to users
    user_scores = {unique_users[idx]: score for idx, score in enumerate(user_scores_vector)}

    # Rank users by scores
    ranked_users = sorted(user_scores.items(), key=lambda x: x[1], reverse=True)
    return ranked_users[:top_n]

# %%
recommend_users(tags)
# Out:
# [(10221765, 6961.702194773498),
#  (1447675, 4605.880020042108),
#  (8620333, 4087.286736965725),
#  (9819146, 3710.3940115563155),
#  (9515207, 3539.796342985606),
#  (9624435, 2442.6682320166447),
#  (19068, 2440.0811180705978),
#  (6766919, 2413.3835273305526),
#  (5260024, 2327.524737705065),
#  (157247, 2152.4099257192697)]
