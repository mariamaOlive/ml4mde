# %% [markdown]
# # Rec Sys of Answerers for StackOverflow
# ## Version 1.0

# %% [markdown]
# Loading Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from collections import defaultdict
from scipy.sparse import csr_matrix
from scipy.sparse.linalg import norm
from sklearn.model_selection import train_test_split
import ast

# %% [markdown]
# Loading Data

# %%
df_question = pd.read_csv("dataset/questions_2019.csv")
df_answer = pd.read_csv("dataset/answers_2019.csv")

# %%
df_question.head()
# Out:
#    QuestionId  QuestionOwnerId  \
# 0    54936100          3419772
# 1    54936106          3997132
# 2    54936108          4992551
# 3    54936109          2239552
# 4    54936112          5505171
#
#                                        QuestionTitle  \
# 0      R 3.5.2: Error in loading stock data from zoo
# 1        Different behaviour of range with lodash/fp
# 2  webPack dev server proxy rewrite URLs in response
# 3                          EF Core 2.0 Global Filter
# 4  Clustered column chart in C# using Chart in Wi...
#
#                                    QuestionTags  QuestionVotes  \
# 0                                         ['r']              0
# 1          ['functional-programming', 'lodash']              1
# 2             ['webpack', 'webpack-dev-server']              2
# 3                                        ['c#']              0
# 4  ['c#', 'winforms', 'charts', 'column-chart']              0
#
#   QuestionCreationDate  AnswerCount
# 0  2019-03-01 00:00:10            1
# 1  2019-03-01 00:01:48            1
# 2  2019-03-01 00:01:55            1
# 3  2019-03-01 00:02:36            0
# 4  2019-03-01 00:02:47            0

# %%
df_answer.head()
# Out:
#    QuestionId  AnswerOwnerId  AnswerVotes   AnswerCreationDate
# 0    56140111       10245958            3  2019-05-15 00:07:23
# 1    56140157        1226963            0  2019-05-15 00:12:34
# 2    56140125        6841773            0  2019-05-15 00:12:44
# 3    56140150        1440565            5  2019-05-15 00:12:52
# 4    56140150       11015427           15  2019-05-15 00:16:46

# %% [markdown]
# Transfoming list of tags

# %%
df_question['QuestionTags'] = df_question['QuestionTags'].apply(ast.literal_eval)

# %%
df_question
# Out:
#         QuestionId  QuestionOwnerId  \
# 0         54936100          3419772
# 1         54936106          3997132
# 2         54936108          4992551
# 3         54936109          2239552
# 4         54936112          5505171
# ...            ...              ...
# 878713    54272409         10245420
# 878714    54272411          8906835
# 878715    54272412         10893334
# 878716    54272414         10564619
# 878717    54272418         10934024
#
#                                             QuestionTitle  \
# 0           R 3.5.2: Error in loading stock data from zoo
# 1             Different behaviour of range with lodash/fp
# 2       webPack dev server proxy rewrite URLs in response
# 3                               EF Core 2.0 Global Filter
# 4       Clustered column chart in C# using Chart in Wi...
# ...                                                   ...
# 878713                Selenium iframe Data issue - python
# 878714     Problem on adding Bootstrap carousel component
# 878715  NativeScript Vue nativescript-sqlite cannot as...
# 878716  How to fix 'TypeError' that comes up for some ...
# 878717  Getting only a repeating files from directory ...
#
#                                           QuestionTags  QuestionVotes  \
# 0                                                  [r]              0
# 1                     [functional-programming, lodash]              1
# 2                        [webpack, webpack-dev-server]              2
# 3                                                 [c#]              0
# 4                 [c#, winforms, charts, column-chart]              0
# ...                                                ...            ...
# 878713  [python, selenium, selenium-webdriver, iframe]              1
# 878714               [bootstrap-4, bootstrap-carousel]              0
# 878715        [sqlite, nativescript, nativescript-vue]              0
# 878716                             [python, typeerror]              1
# 878717        [powershell, csv, unique, get-childitem]              1
#
#        QuestionCreationDate  AnswerCount
# 0       2019-03-01 00:00:10            1
# 1       2019-03-01 00:01:48            1
# 2       2019-03-01 00:01:55            1
# 3       2019-03-01 00:02:36            0
# 4       2019-03-01 00:02:47            0
# ...                     ...          ...
# 878713  2019-01-19 23:57:14            1
# 878714  2019-01-19 23:57:26            1
# 878715  2019-01-19 23:57:36            1
# 878716  2019-01-19 23:57:54            1
# 878717  2019-01-19 23:59:27            1
#
# [878718 rows x 7 columns]

# %% [markdown]
# Tranforming upvotes (df_answer)

# %%
epsilon = 1

# Adjust upvotes
df_answer['adjusted_upvotes'] = df_answer['AnswerVotes'].apply(lambda x: x + epsilon if x >= 0 else x)

# Apply transformation (for considering also negative values)
df_answer['transformed_upvotes'] = df_answer['adjusted_upvotes'].apply(
    lambda x: np.log1p(x) if x > 0 else -np.log1p(abs(x))
)

# %% [markdown]
# ## Prototype 1 - Approach Collaborative Filtering
#
#
# - **Goal:** Find answerers to new posted question.
#
# - **Approach:** Collaborative Filtering (Item Based) --> Utilize question tags of previous answered questions, to indicate the most appropriate user.
#
# - **Steps:**
#
# 1. Create Matrix of User-Tags
# 2. Calculate cosine similarity between tags
# 3. Calculate the the score of the user given the number of times they answerered certain question and the similarity of that tag with the the tags of the new question.

# %% [markdown]
# ### Dividing the question dataset into Train and Test

# %%
train_data, test_data = train_test_split(df_question, test_size=0.05, random_state=42)

# %% [markdown]
# Merging QuestionTags to UserAnswerId

# %%
df_merged = train_data[["QuestionId","QuestionTags"]].merge(df_answer[["QuestionId", "AnswerOwnerId", "transformed_upvotes"]], how='inner', on = "QuestionId", )

# %% [markdown]
# ### Indexing tags and users

# %%
dic_merged = df_merged.to_dict(orient="records")

# %%
unique_tags = list({tag for question in dic_merged for tag in question['QuestionTags']})
unique_users = list({question['AnswerOwnerId'] for question in dic_merged})

tag_to_index = {tag: idx for idx, tag in enumerate(unique_tags)}
user_to_index = {user: idx for idx, user in enumerate(unique_users)}

# %%
dic_merged
# Out:
# [{'QuestionId': 56131754,
#   'QuestionTags': ['c'],
#   'AnswerOwnerId': 45685,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56131754,
#   'QuestionTags': ['c'],
#   'AnswerOwnerId': 7310570,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55161024,
#   'QuestionTags': ['java', 'spring', 'spring-boot', 'aspectj'],
#   'AnswerOwnerId': 12029935,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55161024,
#   'QuestionTags': ['java', 'spring', 'spring-boot', 'aspectj'],
#   'AnswerOwnerId': 14349319,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54288605,
#   'QuestionTags': ['php', 'mysql'],
#   'AnswerOwnerId': 4903440,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54566354,
#   'QuestionTags': ['java', 'knapsack-problem'],
#   'AnswerOwnerId': 2952011,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54566354,
#   'QuestionTags': ['java', 'knapsack-problem'],
#   'AnswerOwnerId': 10232790,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56291248,
#   'QuestionTags': ['javascript', 'sapui5'],
#   'AnswerOwnerId': 3702797,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56331871,
#   'QuestionTags': ['python', 'xml'],
#   'AnswerOwnerId': 415016,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55662634,
#   'QuestionTags': ['javascript', 'node.js', 'vue.js', 'nuxt.js'],
#   'AnswerOwnerId': 6530898,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54657208,
#   'QuestionTags': ['batch-file', 'cmd'],
#   'AnswerOwnerId': 11047851,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56761853,
#   'QuestionTags': ['git', 'jenkins'],
#   'AnswerOwnerId': 243563,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54333050,
#   'QuestionTags': ['utf-8', 'inno-setup', 'byte-order-mark'],
#   'AnswerOwnerId': 850848,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 56262530,
#   'QuestionTags': ['kotlin', 'collections', 'covariance'],
#   'AnswerOwnerId': 2196460,
#   'transformed_upvotes': 2.3978952727983707},
#  {'QuestionId': 54753219,
#   'QuestionTags': ['r', 'dataframe', 'subset'],
#   'AnswerOwnerId': 8389003,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 56170141,
#   'QuestionTags': ['javascript', 'facebook', 'facebook-graph-api', 'axios'],
#   'AnswerOwnerId': 10955263,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55598864,
#   'QuestionTags': ['c#', 'asp.net-core'],
#   'AnswerOwnerId': 10158551,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56472082,
#   'QuestionTags': ['c#', 'asp.net-mvc', 'model-view-controller'],
#   'AnswerOwnerId': 5233410,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 56472082,
#   'QuestionTags': ['c#', 'asp.net-mvc', 'model-view-controller'],
#   'AnswerOwnerId': 7651458,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55511022,
#   'QuestionTags': ['c++'],
#   'AnswerOwnerId': 4117728,
#   'transformed_upvotes': 2.0794415416798357},
#  {'QuestionId': 55511022,
#   'QuestionTags': ['c++'],
#   'AnswerOwnerId': 4967403,
#   'transformed_upvotes': 2.0794415416798357},
#  {'QuestionId': 55511022,
#   'QuestionTags': ['c++'],
#   'AnswerOwnerId': 3696464,
#   'transformed_upvotes': -1.6094379124341003},
#  {'QuestionId': 56759400,
#   'QuestionTags': ['button', 'botframework', 'bots', 'slack'],
#   'AnswerOwnerId': 3962636,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56759400,
#   'QuestionTags': ['button', 'botframework', 'bots', 'slack'],
#   'AnswerOwnerId': 1390924,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56550905,
#   'QuestionTags': ['javascript',
#    'html',
#    'innerhtml',
#    'getelementbyid',
#    'html-injections'],
#   'AnswerOwnerId': 1669671,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56550905,
#   'QuestionTags': ['javascript',
#    'html',
#    'innerhtml',
#    'getelementbyid',
#    'html-injections'],
#   'AnswerOwnerId': 4828524,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56650624,
#   'QuestionTags': ['javascript', 'batch-file', 'hta'],
#   'AnswerOwnerId': 778560,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 56119399,
#   'QuestionTags': ['python', 'graph', 'networkx'],
#   'AnswerOwnerId': 8544179,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56119399,
#   'QuestionTags': ['python', 'graph', 'networkx'],
#   'AnswerOwnerId': 3081730,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55986454,
#   'QuestionTags': ['c#', 'docker', 'docker-compose', 'docker-volume'],
#   'AnswerOwnerId': 7717185,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 54767370,
#   'QuestionTags': ['javascript', 'arrays'],
#   'AnswerOwnerId': 10498106,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56164588,
#   'QuestionTags': ['javascript', 'jquery', 'html', 'css', 'highcharts'],
#   'AnswerOwnerId': 6108882,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 56164588,
#   'QuestionTags': ['javascript', 'jquery', 'html', 'css', 'highcharts'],
#   'AnswerOwnerId': 8951377,
#   'transformed_upvotes': 1.9459101490553132},
#  {'QuestionId': 54343480,
#   'QuestionTags': ['azure-iot-edge'],
#   'AnswerOwnerId': 1195137,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 54343480,
#   'QuestionTags': ['azure-iot-edge'],
#   'AnswerOwnerId': 5321299,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54354499,
#   'QuestionTags': ['reactjs', 'react-native', 'react-native-navigation'],
#   'AnswerOwnerId': 7635085,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54354499,
#   'QuestionTags': ['reactjs', 'react-native', 'react-native-navigation'],
#   'AnswerOwnerId': 5508175,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54058715,
#   'QuestionTags': ['python', 'list', 'flatten'],
#   'AnswerOwnerId': 5576268,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 54058715,
#   'QuestionTags': ['python', 'list', 'flatten'],
#   'AnswerOwnerId': 10638232,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56471464,
#   'QuestionTags': ['json', 'swift'],
#   'AnswerOwnerId': 7346775,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55591770,
#   'QuestionTags': ['kubernetes', 'nginx-ingress'],
#   'AnswerOwnerId': 2853439,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54626238,
#   'QuestionTags': ['ruby-on-rails', 'activerecord'],
#   'AnswerOwnerId': 10522579,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 54626238,
#   'QuestionTags': ['ruby-on-rails', 'activerecord'],
#   'AnswerOwnerId': 6384607,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54897051,
#   'QuestionTags': ['zurb-foundation'],
#   'AnswerOwnerId': 145574,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54245713,
#   'QuestionTags': ['python',
#    'selenium',
#    'selenium-webdriver',
#    'selenium-chromedriver'],
#   'AnswerOwnerId': 9657108,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56235187,
#   'QuestionTags': ['python-3.x', 'list', 'dictionary'],
#   'AnswerOwnerId': 1518924,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56235187,
#   'QuestionTags': ['python-3.x', 'list', 'dictionary'],
#   'AnswerOwnerId': 532312,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56235187,
#   'QuestionTags': ['python-3.x', 'list', 'dictionary'],
#   'AnswerOwnerId': 11532789,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54225971,
#   'QuestionTags': ['rest', 'hl7', 'mirth', 'mirth-connect'],
#   'AnswerOwnerId': 10519543,
#   'transformed_upvotes': 1.791759469228055},
#  {'QuestionId': 54225971,
#   'QuestionTags': ['rest', 'hl7', 'mirth', 'mirth-connect'],
#   'AnswerOwnerId': 3005941,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55536646,
#   'QuestionTags': ['python',
#    'django',
#    'request',
#    'http-status-code-404',
#    'urlconf'],
#   'AnswerOwnerId': 5886576,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 55536646,
#   'QuestionTags': ['python',
#    'django',
#    'request',
#    'http-status-code-404',
#    'urlconf'],
#   'AnswerOwnerId': 5600452,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55536646,
#   'QuestionTags': ['python',
#    'django',
#    'request',
#    'http-status-code-404',
#    'urlconf'],
#   'AnswerOwnerId': 13361320,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55536646,
#   'QuestionTags': ['python',
#    'django',
#    'request',
#    'http-status-code-404',
#    'urlconf'],
#   'AnswerOwnerId': 14670626,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55536646,
#   'QuestionTags': ['python',
#    'django',
#    'request',
#    'http-status-code-404',
#    'urlconf'],
#   'AnswerOwnerId': 16053637,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55014583,
#   'QuestionTags': ['c#', 'excel', 'file', 'readonly'],
#   'AnswerOwnerId': 5262163,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55014583,
#   'QuestionTags': ['c#', 'excel', 'file', 'readonly'],
#   'AnswerOwnerId': 1621397,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54302791,
#   'QuestionTags': ['bash'],
#   'AnswerOwnerId': 5411198,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54302791,
#   'QuestionTags': ['bash'],
#   'AnswerOwnerId': 10948490,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54426598,
#   'QuestionTags': ['arangodb'],
#   'AnswerOwnerId': 3237176,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54680609,
#   'QuestionTags': ['daml'],
#   'AnswerOwnerId': 1196234,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 55776592,
#   'QuestionTags': ['ios', 'model-view-controller', 'uiviewcontroller'],
#   'AnswerOwnerId': 341994,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54395586,
#   'QuestionTags': ['android',
#    'firebase',
#    'android-fragments',
#    'push-notification',
#    'firebase-cloud-messaging'],
#   'AnswerOwnerId': 3122596,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54395586,
#   'QuestionTags': ['android',
#    'firebase',
#    'android-fragments',
#    'push-notification',
#    'firebase-cloud-messaging'],
#   'AnswerOwnerId': 3051503,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54259656,
#   'QuestionTags': ['python'],
#   'AnswerOwnerId': 8956917,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54259656,
#   'QuestionTags': ['python'],
#   'AnswerOwnerId': 8300135,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 54259656,
#   'QuestionTags': ['python'],
#   'AnswerOwnerId': 17221009,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54839392,
#   'QuestionTags': ['c#', 'json'],
#   'AnswerOwnerId': 1744164,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54839392,
#   'QuestionTags': ['c#', 'json'],
#   'AnswerOwnerId': 1343192,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54839392,
#   'QuestionTags': ['c#', 'json'],
#   'AnswerOwnerId': 403671,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55255517,
#   'QuestionTags': ['angular', 'rxjs'],
#   'AnswerOwnerId': 310726,
#   'transformed_upvotes': 1.9459101490553132},
#  {'QuestionId': 54203908,
#   'QuestionTags': ['sql-server', 'spring-boot', 'db2', 'hsqldb'],
#   'AnswerOwnerId': 471070,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55468431,
#   'QuestionTags': ['java', 'android', 'android-alertdialog'],
#   'AnswerOwnerId': 11271840,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56120904,
#   'QuestionTags': ['python'],
#   'AnswerOwnerId': 390278,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56120904,
#   'QuestionTags': ['python'],
#   'AnswerOwnerId': 11478528,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55487539,
#   'QuestionTags': ['python', 'json', 'dictionary', 'geojson'],
#   'AnswerOwnerId': 7752296,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56742400,
#   'QuestionTags': ['java', 'blob', 'blobstore'],
#   'AnswerOwnerId': 1645712,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54932516,
#   'QuestionTags': ['java', 'jvm', 'classloader'],
#   'AnswerOwnerId': 1392277,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 54462782,
#   'QuestionTags': ['amazon-web-services', 'aws-lambda'],
#   'AnswerOwnerId': 2800876,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 54368049,
#   'QuestionTags': ['amazon-web-services',
#    'aws-lambda',
#    'jwt',
#    'amazon-cognito'],
#   'AnswerOwnerId': 2426627,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54368049,
#   'QuestionTags': ['amazon-web-services',
#    'aws-lambda',
#    'jwt',
#    'amazon-cognito'],
#   'AnswerOwnerId': 4812170,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 54368049,
#   'QuestionTags': ['amazon-web-services',
#    'aws-lambda',
#    'jwt',
#    'amazon-cognito'],
#   'AnswerOwnerId': 14286030,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54186407,
#   'QuestionTags': ['xamarin.forms'],
#   'AnswerOwnerId': 7462031,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55967441,
#   'QuestionTags': ['laravel', 'sitemap'],
#   'AnswerOwnerId': 5191800,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54300931,
#   'QuestionTags': ['python-3.x'],
#   'AnswerOwnerId': 10611983,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 54077501,
#   'QuestionTags': ['groovy', 'groovyscriptengine'],
#   'AnswerOwnerId': 6014014,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54830058,
#   'QuestionTags': ['python', 'bash', 'input', 'io-redirection'],
#   'AnswerOwnerId': 2084384,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54830058,
#   'QuestionTags': ['python', 'bash', 'input', 'io-redirection'],
#   'AnswerOwnerId': 3545273,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55790876,
#   'QuestionTags': ['ios', 'swift', 'augmented-reality', 'arkit', 'measure'],
#   'AnswerOwnerId': 6599590,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56729368,
#   'QuestionTags': ['react-native', 'react-redux', 'redux-persist'],
#   'AnswerOwnerId': 11680526,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54076704,
#   'QuestionTags': ['node.js', 'express', 'smtp', 'nodemailer'],
#   'AnswerOwnerId': 10828775,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55699129,
#   'QuestionTags': ['python', 'python-3.x'],
#   'AnswerOwnerId': 9921041,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 55699129,
#   'QuestionTags': ['python', 'python-3.x'],
#   'AnswerOwnerId': 189247,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56412323,
#   'QuestionTags': ['javascript', 'css', 'bootstrap-4', 'font-awesome', 'nav'],
#   'AnswerOwnerId': 8757883,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54177852,
#   'QuestionTags': ['java', 'selenium', 'automation', 'automated-tests'],
#   'AnswerOwnerId': 10882257,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54177852,
#   'QuestionTags': ['java', 'selenium', 'automation', 'automated-tests'],
#   'AnswerOwnerId': 9303641,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54177852,
#   'QuestionTags': ['java', 'selenium', 'automation', 'automated-tests'],
#   'AnswerOwnerId': 6069910,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54427370,
#   'QuestionTags': ['javascript',
#    'css-transitions',
#    'transition',
#    'addeventlistener'],
#   'AnswerOwnerId': 9078341,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 56691427,
#   'QuestionTags': ['android', 'bash', 'sh', 'adb'],
#   'AnswerOwnerId': 5515843,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56691427,
#   'QuestionTags': ['android', 'bash', 'sh', 'adb'],
#   'AnswerOwnerId': 5515843,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56691427,
#   'QuestionTags': ['android', 'bash', 'sh', 'adb'],
#   'AnswerOwnerId': 846536,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55767940,
#   'QuestionTags': ['wordpress', 'azure', 'virtual-machine'],
#   'AnswerOwnerId': 1347366,
#   'transformed_upvotes': 1.9459101490553132},
#  {'QuestionId': 55767940,
#   'QuestionTags': ['wordpress', 'azure', 'virtual-machine'],
#   'AnswerOwnerId': 4864255,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 56488740,
#   'QuestionTags': ['java', 'simpledateformat'],
#   'AnswerOwnerId': 7746398,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56488740,
#   'QuestionTags': ['java', 'simpledateformat'],
#   'AnswerOwnerId': 992484,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 55282022,
#   'QuestionTags': ['python-3.x', 'tkinter', 'tabs'],
#   'AnswerOwnerId': 5604827,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 55282022,
#   'QuestionTags': ['python-3.x', 'tkinter', 'tabs'],
#   'AnswerOwnerId': 15914159,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55574776,
#   'QuestionTags': ['ansible'],
#   'AnswerOwnerId': 147356,
#   'transformed_upvotes': 1.9459101490553132},
#  {'QuestionId': 55436786,
#   'QuestionTags': ['mysql', 'sql'],
#   'AnswerOwnerId': 10676716,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 56505120,
#   'QuestionTags': ['javascript', 'css', 'twitter-bootstrap'],
#   'AnswerOwnerId': 14418291,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56797072,
#   'QuestionTags': ['java', 'spring', 'spring-boot', 'exception'],
#   'AnswerOwnerId': 1753823,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 54512441,
#   'QuestionTags': ['java', 'enums', 'legacy', 'objectmapper'],
#   'AnswerOwnerId': 8370004,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56403243,
#   'QuestionTags': ['python', 'kivy', 'kivy-language'],
#   'AnswerOwnerId': 6366098,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 54392346,
#   'QuestionTags': ['html', 'reactjs', 'image', 'npm', 'create-react-app'],
#   'AnswerOwnerId': 8412187,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54784455,
#   'QuestionTags': ['javascript', 'angular', 'angular2-modules'],
#   'AnswerOwnerId': 10161335,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54784455,
#   'QuestionTags': ['javascript', 'angular', 'angular2-modules'],
#   'AnswerOwnerId': 7796179,
#   'transformed_upvotes': 1.791759469228055},
#  {'QuestionId': 54784455,
#   'QuestionTags': ['javascript', 'angular', 'angular2-modules'],
#   'AnswerOwnerId': 3690301,
#   'transformed_upvotes': 2.3978952727983707},
#  {'QuestionId': 55144600,
#   'QuestionTags': ['perl', 'csv', 'sorting', 'unix', 'unique'],
#   'AnswerOwnerId': 1483318,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54894756,
#   'QuestionTags': ['javascript', 'node.js'],
#   'AnswerOwnerId': 1447675,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54894756,
#   'QuestionTags': ['javascript', 'node.js'],
#   'AnswerOwnerId': 4570698,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54894756,
#   'QuestionTags': ['javascript', 'node.js'],
#   'AnswerOwnerId': 10221765,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54894756,
#   'QuestionTags': ['javascript', 'node.js'],
#   'AnswerOwnerId': 4959547,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54894756,
#   'QuestionTags': ['javascript', 'node.js'],
#   'AnswerOwnerId': 5156280,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54923591,
#   'QuestionTags': ['visual-studio', 'visual-studio-2017', 'product-key'],
#   'AnswerOwnerId': 284704,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54923591,
#   'QuestionTags': ['visual-studio', 'visual-studio-2017', 'product-key'],
#   'AnswerOwnerId': 2087791,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54573748,
#   'QuestionTags': ['java', 'html', 'spring', 'thymeleaf', 'jpa-annotations'],
#   'AnswerOwnerId': 7401569,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54573748,
#   'QuestionTags': ['java', 'html', 'spring', 'thymeleaf', 'jpa-annotations'],
#   'AnswerOwnerId': 6583444,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55592381,
#   'QuestionTags': ['arrays', 'reactjs', 'random', 'react-hooks'],
#   'AnswerOwnerId': 8240061,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 55592381,
#   'QuestionTags': ['arrays', 'reactjs', 'random', 'react-hooks'],
#   'AnswerOwnerId': 1289344,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 55308450,
#   'QuestionTags': ['r'],
#   'AnswerOwnerId': 11071807,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55308450,
#   'QuestionTags': ['r'],
#   'AnswerOwnerId': 202229,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54837438,
#   'QuestionTags': ['c++', 'multithreading'],
#   'AnswerOwnerId': 721269,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 54837438,
#   'QuestionTags': ['c++', 'multithreading'],
#   'AnswerOwnerId': 2079303,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54837438,
#   'QuestionTags': ['c++', 'multithreading'],
#   'AnswerOwnerId': 4474230,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54757329,
#   'QuestionTags': ['ios',
#    'swift',
#    'uicollectionview',
#    'scrollview',
#    'touch-up-inside'],
#   'AnswerOwnerId': 10335956,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54432299,
#   'QuestionTags': ['php', 'database', 'laravel', 'laravel-5.4'],
#   'AnswerOwnerId': 9344853,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56818245,
#   'QuestionTags': ['r', 'lubridate'],
#   'AnswerOwnerId': 10323798,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 56818245,
#   'QuestionTags': ['r', 'lubridate'],
#   'AnswerOwnerId': 3962914,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 56818245,
#   'QuestionTags': ['r', 'lubridate'],
#   'AnswerOwnerId': 3732271,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 54182754,
#   'QuestionTags': ['spring-boot',
#    'ssl',
#    'ssl-certificate',
#    'spring-boot-actuator'],
#   'AnswerOwnerId': 8294118,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54342852,
#   'QuestionTags': ['c#', 'model-view-controller'],
#   'AnswerOwnerId': 6391339,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54884874,
#   'QuestionTags': ['python-3.x', 'docker'],
#   'AnswerOwnerId': 576932,
#   'transformed_upvotes': 1.791759469228055},
#  {'QuestionId': 54416541,
#   'QuestionTags': ['java'],
#   'AnswerOwnerId': 2798897,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54230924,
#   'QuestionTags': ['javascript', 'jquery', 'ajax', 'datatables'],
#   'AnswerOwnerId': 4119695,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56279160,
#   'QuestionTags': ['python',
#    'multithreading',
#    'methods',
#    'pygame',
#    'switch-statement'],
#   'AnswerOwnerId': 10924296,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56669420,
#   'QuestionTags': ['sql-server-2012'],
#   'AnswerOwnerId': 11670870,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 56669420,
#   'QuestionTags': ['sql-server-2012'],
#   'AnswerOwnerId': 2672592,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56814694,
#   'QuestionTags': ['postgresql'],
#   'AnswerOwnerId': 9929134,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56814694,
#   'QuestionTags': ['postgresql'],
#   'AnswerOwnerId': 340688,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56814694,
#   'QuestionTags': ['postgresql'],
#   'AnswerOwnerId': 895640,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55121331,
#   'QuestionTags': ['asp.net-web-api', 'query-string'],
#   'AnswerOwnerId': 4964569,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55576130,
#   'QuestionTags': ['matlab', 'ode'],
#   'AnswerOwnerId': 7054628,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56493824,
#   'QuestionTags': ['python', 'dictionary'],
#   'AnswerOwnerId': 3208297,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56493824,
#   'QuestionTags': ['python', 'dictionary'],
#   'AnswerOwnerId': 11532789,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55422664,
#   'QuestionTags': ['sql', 'sql-server', 'sql-injection'],
#   'AnswerOwnerId': 11029048,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55422664,
#   'QuestionTags': ['sql', 'sql-server', 'sql-injection'],
#   'AnswerOwnerId': 134204,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 55422664,
#   'QuestionTags': ['sql', 'sql-server', 'sql-injection'],
#   'AnswerOwnerId': 208567,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54914313,
#   'QuestionTags': ['php', 'laravel', 'image'],
#   'AnswerOwnerId': 439135,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56677810,
#   'QuestionTags': ['c++'],
#   'AnswerOwnerId': 11661915,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 56677810,
#   'QuestionTags': ['c++'],
#   'AnswerOwnerId': 7331107,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54535213,
#   'QuestionTags': ['javascript', 'reactjs', 'react-native'],
#   'AnswerOwnerId': 4862255,
#   'transformed_upvotes': -1.0986122886681098},
#  {'QuestionId': 54535213,
#   'QuestionTags': ['javascript', 'reactjs', 'react-native'],
#   'AnswerOwnerId': 4026902,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54535213,
#   'QuestionTags': ['javascript', 'reactjs', 'react-native'],
#   'AnswerOwnerId': 9723036,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55131724,
#   'QuestionTags': ['c#', 'wpf', 'custom-controls'],
#   'AnswerOwnerId': 1136211,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55575450,
#   'QuestionTags': ['ruby-on-rails', 'sendgrid'],
#   'AnswerOwnerId': 125816,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 55350236,
#   'QuestionTags': ['wordpress', 'ionic-framework', 'woocommerce', 'ionic3'],
#   'AnswerOwnerId': 9798051,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 55359197,
#   'QuestionTags': ['javascript', 'firefox', 'popup'],
#   'AnswerOwnerId': 854540,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54293106,
#   'QuestionTags': ['c#', 'asp.net', 'asp.net-mvc', 'sweetalert'],
#   'AnswerOwnerId': 4205875,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54171004,
#   'QuestionTags': ['node.js', 'mongoose', 'mongoose-schema'],
#   'AnswerOwnerId': 10808498,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55385919,
#   'QuestionTags': ['javascript', 'angular'],
#   'AnswerOwnerId': 3794812,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55385919,
#   'QuestionTags': ['javascript', 'angular'],
#   'AnswerOwnerId': 11135174,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54952619,
#   'QuestionTags': ['asp.net-core', 'imageresizer'],
#   'AnswerOwnerId': 7075463,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 54952619,
#   'QuestionTags': ['asp.net-core', 'imageresizer'],
#   'AnswerOwnerId': 166893,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54212466,
#   'QuestionTags': ['node.js', 'gitlab-ci', 'puppeteer'],
#   'AnswerOwnerId': 1620805,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55873657,
#   'QuestionTags': ['powershell', 'cmd', 'administrator', 'sta'],
#   'AnswerOwnerId': 11417478,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55873657,
#   'QuestionTags': ['powershell', 'cmd', 'administrator', 'sta'],
#   'AnswerOwnerId': 3245749,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54231165,
#   'QuestionTags': ['database', 'laravel', 'laravel-query-builder'],
#   'AnswerOwnerId': 3332862,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54231165,
#   'QuestionTags': ['database', 'laravel', 'laravel-query-builder'],
#   'AnswerOwnerId': 9294616,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55424439,
#   'QuestionTags': ['cplex'],
#   'AnswerOwnerId': 3725596,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55424439,
#   'QuestionTags': ['cplex'],
#   'AnswerOwnerId': 4177,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55149650,
#   'QuestionTags': ['r', 'data-cleaning'],
#   'AnswerOwnerId': 9927286,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55858218,
#   'QuestionTags': ['amazon-dynamodb', 'amazon-dynamodb-index'],
#   'AnswerOwnerId': 2371805,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56785967,
#   'QuestionTags': ['php', 'laravel', 'laravel-routing'],
#   'AnswerOwnerId': 2867881,
#   'transformed_upvotes': 2.0794415416798357},
#  {'QuestionId': 56785967,
#   'QuestionTags': ['php', 'laravel', 'laravel-routing'],
#   'AnswerOwnerId': 4101154,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 55895297,
#   'QuestionTags': ['c++'],
#   'AnswerOwnerId': 5231607,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55153758,
#   'QuestionTags': ['microsoft-graph-api'],
#   'AnswerOwnerId': 26843,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54057424,
#   'QuestionTags': ['php', 'wordpress', 'shortcode'],
#   'AnswerOwnerId': 9645594,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56608246,
#   'QuestionTags': ['php', 'http-headers', 'google-api-php-client', 'referer'],
#   'AnswerOwnerId': 10486051,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 54221794,
#   'QuestionTags': ['javascript', 'ajax', 'xmlhttprequest'],
#   'AnswerOwnerId': 7070823,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 54308448,
#   'QuestionTags': ['c', 'debugging', 'keil', 'jtag', 'step-through'],
#   'AnswerOwnerId': 11634446,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55886308,
#   'QuestionTags': ['node.js', 'express'],
#   'AnswerOwnerId': 7825351,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55886308,
#   'QuestionTags': ['node.js', 'express'],
#   'AnswerOwnerId': 7185241,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56541926,
#   'QuestionTags': ['java', 'splash-screen'],
#   'AnswerOwnerId': 875083,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55693993,
#   'QuestionTags': ['laravel', 'laraadmin'],
#   'AnswerOwnerId': 1457270,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55693993,
#   'QuestionTags': ['laravel', 'laraadmin'],
#   'AnswerOwnerId': 8767899,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56051535,
#   'QuestionTags': ['c#'],
#   'AnswerOwnerId': 120955,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56051535,
#   'QuestionTags': ['c#'],
#   'AnswerOwnerId': 259769,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55589342,
#   'QuestionTags': ['javascript', 'jquery'],
#   'AnswerOwnerId': 519413,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55589342,
#   'QuestionTags': ['javascript', 'jquery'],
#   'AnswerOwnerId': 11328122,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56403199,
#   'QuestionTags': ['microsoft-graph-api', 'microsoft-graph-calendar'],
#   'AnswerOwnerId': 105518,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56633998,
#   'QuestionTags': ['excel', 'vba'],
#   'AnswerOwnerId': 5720144,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54483243,
#   'QuestionTags': ['java', 'android', 'xml', 'animation'],
#   'AnswerOwnerId': 7604766,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55424320,
#   'QuestionTags': ['r'],
#   'AnswerOwnerId': 8583393,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 55300592,
#   'QuestionTags': ['scilab', 'integral'],
#   'AnswerOwnerId': 9595931,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55224907,
#   'QuestionTags': ['android',
#    'google-maps',
#    'google-maps-api-3',
#    'android-location'],
#   'AnswerOwnerId': 4120431,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54698036,
#   'QuestionTags': ['azure-logic-apps'],
#   'AnswerOwnerId': 10383250,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 55280788,
#   'QuestionTags': ['python', 'windows', 'console', 'remote-access', 'fabric'],
#   'AnswerOwnerId': 6043170,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56740103,
#   'QuestionTags': ['python-2.7', 'py2exe'],
#   'AnswerOwnerId': 3116731,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54384095,
#   'QuestionTags': ['python-3.x', 'matplotlib', 'hover'],
#   'AnswerOwnerId': 10944175,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55941823,
#   'QuestionTags': ['sql', 'sql-server'],
#   'AnswerOwnerId': 11305906,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 56646742,
#   'QuestionTags': ['go', 'proto'],
#   'AnswerOwnerId': 1218512,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56538728,
#   'QuestionTags': ['typescript'],
#   'AnswerOwnerId': 2887218,
#   'transformed_upvotes': 1.791759469228055},
#  {'QuestionId': 56444730,
#   'QuestionTags': ['javascript', 'arrays', 'object'],
#   'AnswerOwnerId': 2034850,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56444730,
#   'QuestionTags': ['javascript', 'arrays', 'object'],
#   'AnswerOwnerId': 6105280,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55118747,
#   'QuestionTags': ['python', 'arrays', 'algorithm'],
#   'AnswerOwnerId': 6074182,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 55118747,
#   'QuestionTags': ['python', 'arrays', 'algorithm'],
#   'AnswerOwnerId': 844416,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 55118747,
#   'QuestionTags': ['python', 'arrays', 'algorithm'],
#   'AnswerOwnerId': 4249714,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54596446,
#   'QuestionTags': ['knockout.js', 'control-flow'],
#   'AnswerOwnerId': 3082296,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55971796,
#   'QuestionTags': ['powershell'],
#   'AnswerOwnerId': 447901,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55971796,
#   'QuestionTags': ['powershell'],
#   'AnswerOwnerId': 9898643,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54305745,
#   'QuestionTags': ['c++', 'qt5', 'qscintilla'],
#   'AnswerOwnerId': 10320907,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55902466,
#   'QuestionTags': ['mysql', 'sql', 'performance'],
#   'AnswerOwnerId': 1144035,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55902466,
#   'QuestionTags': ['mysql', 'sql', 'performance'],
#   'AnswerOwnerId': 1766831,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56336476,
#   'QuestionTags': ['casting', 'xquery'],
#   'AnswerOwnerId': 252228,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 54347286,
#   'QuestionTags': ['delphi', 'tstringgrid'],
#   'AnswerOwnerId': 2292722,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56105998,
#   'QuestionTags': ['database', 'extjs', 'store'],
#   'AnswerOwnerId': 8904014,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54902319,
#   'QuestionTags': ['variables', 'path', 'naming-conventions'],
#   'AnswerOwnerId': 337149,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54496026,
#   'QuestionTags': ['python', 'python-3.x', 'for-loop', 'if-statement'],
#   'AnswerOwnerId': 100297,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 55005340,
#   'QuestionTags': ['java', 'dry', 'design-principles'],
#   'AnswerOwnerId': 1531124,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55005340,
#   'QuestionTags': ['java', 'dry', 'design-principles'],
#   'AnswerOwnerId': 1602555,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55005340,
#   'QuestionTags': ['java', 'dry', 'design-principles'],
#   'AnswerOwnerId': 34088,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55005340,
#   'QuestionTags': ['java', 'dry', 'design-principles'],
#   'AnswerOwnerId': 6772373,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54772444,
#   'QuestionTags': ['python', 'excel', 'pandas'],
#   'AnswerOwnerId': 9462009,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55191183,
#   'QuestionTags': ['javascript', 'mqtt', 'setinterval', 'node-red'],
#   'AnswerOwnerId': 1079221,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55191183,
#   'QuestionTags': ['javascript', 'mqtt', 'setinterval', 'node-red'],
#   'AnswerOwnerId': 9307866,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55480318,
#   'QuestionTags': ['c', 'postgresql', 'unit-testing'],
#   'AnswerOwnerId': 6464308,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 55004631,
#   'QuestionTags': ['spring-boot', 'spring-cloud-feign', 'netflix-feign'],
#   'AnswerOwnerId': 649605,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56028980,
#   'QuestionTags': ['javascript'],
#   'AnswerOwnerId': 1447675,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 56028980,
#   'QuestionTags': ['javascript'],
#   'AnswerOwnerId': 1686485,
#   'transformed_upvotes': 2.0794415416798357},
#  {'QuestionId': 56028980,
#   'QuestionTags': ['javascript'],
#   'AnswerOwnerId': 3072752,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56282256,
#   'QuestionTags': ['java', 'sql', 'sql-server-2012'],
#   'AnswerOwnerId': 10260396,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55206185,
#   'QuestionTags': ['javascript', 'html', 'css'],
#   'AnswerOwnerId': 5962732,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 55475233,
#   'QuestionTags': ['android', 'deep-linking'],
#   'AnswerOwnerId': 2314969,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55816690,
#   'QuestionTags': ['width', 'html-select', 'fixed-width', 'blueprintjs'],
#   'AnswerOwnerId': 1379329,
#   'transformed_upvotes': -0.6931471805599453},
#  {'QuestionId': 55816690,
#   'QuestionTags': ['width', 'html-select', 'fixed-width', 'blueprintjs'],
#   'AnswerOwnerId': 3412316,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55834669,
#   'QuestionTags': ['java',
#    'date',
#    'datetime',
#    'difference',
#    'date-difference'],
#   'AnswerOwnerId': 2266098,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55834669,
#   'QuestionTags': ['java',
#    'date',
#    'datetime',
#    'difference',
#    'date-difference'],
#   'AnswerOwnerId': 8845030,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55834669,
#   'QuestionTags': ['java',
#    'date',
#    'datetime',
#    'difference',
#    'date-difference'],
#   'AnswerOwnerId': 5772882,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 55902560,
#   'QuestionTags': ['symfony', 'datatable'],
#   'AnswerOwnerId': 7903215,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55902560,
#   'QuestionTags': ['symfony', 'datatable'],
#   'AnswerOwnerId': 9496202,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55728514,
#   'QuestionTags': ['visual-studio', 'xamarin'],
#   'AnswerOwnerId': 7462031,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54848707,
#   'QuestionTags': ['angular', 'mat-table'],
#   'AnswerOwnerId': 5485167,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 54848707,
#   'QuestionTags': ['angular', 'mat-table'],
#   'AnswerOwnerId': 7501273,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56397836,
#   'QuestionTags': ['oracle-database'],
#   'AnswerOwnerId': 266304,
#   'transformed_upvotes': 1.9459101490553132},
#  {'QuestionId': 56340795,
#   'QuestionTags': ['python'],
#   'AnswerOwnerId': 10065878,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56340795,
#   'QuestionTags': ['python'],
#   'AnswerOwnerId': 10878534,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55187736,
#   'QuestionTags': ['java', 'amazon-dynamodb'],
#   'AnswerOwnerId': 2371805,
#   'transformed_upvotes': 1.9459101490553132},
#  {'QuestionId': 56346625,
#   'QuestionTags': ['powershell'],
#   'AnswerOwnerId': 11563638,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56133433,
#   'QuestionTags': ['protocol-buffers'],
#   'AnswerOwnerId': 23354,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55798933,
#   'QuestionTags': ['powershell', 'urlencode', 'slack-api'],
#   'AnswerOwnerId': 4379151,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55798933,
#   'QuestionTags': ['powershell', 'urlencode', 'slack-api'],
#   'AnswerOwnerId': 10291503,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 54502061,
#   'QuestionTags': ['json', 'laravel', 'vue.js', 'vuex'],
#   'AnswerOwnerId': 8172857,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55160627,
#   'QuestionTags': ['javascript'],
#   'AnswerOwnerId': 1846979,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 56674281,
#   'QuestionTags': ['python'],
#   'AnswerOwnerId': 2416958,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 56674281,
#   'QuestionTags': ['python'],
#   'AnswerOwnerId': 6045800,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 56674281,
#   'QuestionTags': ['python'],
#   'AnswerOwnerId': 8786138,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56674281,
#   'QuestionTags': ['python'],
#   'AnswerOwnerId': 11647025,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56674281,
#   'QuestionTags': ['python'],
#   'AnswerOwnerId': 1935238,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 56674281,
#   'QuestionTags': ['python'],
#   'AnswerOwnerId': 14437979,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56496549,
#   'QuestionTags': ['java',
#    'generics',
#    'backwards-compatibility',
#    'java-5',
#    'java1.4'],
#   'AnswerOwnerId': 139985,
#   'transformed_upvotes': 1.791759469228055},
#  {'QuestionId': 56496549,
#   'QuestionTags': ['java',
#    'generics',
#    'backwards-compatibility',
#    'java-5',
#    'java1.4'],
#   'AnswerOwnerId': 183406,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 55827820,
#   'QuestionTags': ['ajax', 'asp.net-mvc-4'],
#   'AnswerOwnerId': 8939811,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56028030,
#   'QuestionTags': ['php', 'laravel', 'laravel-5.8'],
#   'AnswerOwnerId': 1033654,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55340844,
#   'QuestionTags': ['asp.net', 'vb.net', 'visual-studio'],
#   'AnswerOwnerId': 7516,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56449129,
#   'QuestionTags': ['ruby-on-rails', 'ruby'],
#   'AnswerOwnerId': 2483313,
#   'transformed_upvotes': 1.791759469228055},
#  {'QuestionId': 56694713,
#   'QuestionTags': ['python', 'spacy', 'named-entity-recognition'],
#   'AnswerOwnerId': 11930131,
#   'transformed_upvotes': 2.1972245773362196},
#  {'QuestionId': 54888796,
#   'QuestionTags': ['python', 'gis', 'ogr'],
#   'AnswerOwnerId': 12167256,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55088199,
#   'QuestionTags': ['reactjs'],
#   'AnswerOwnerId': 3617886,
#   'transformed_upvotes': 1.791759469228055},
#  {'QuestionId': 55079184,
#   'QuestionTags': ['azerothcore'],
#   'AnswerOwnerId': 7095584,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 56725120,
#   'QuestionTags': ['vue.js', 'vuejs2', 'vue-component', 'vue-router'],
#   'AnswerOwnerId': 9632621,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 54327206,
#   'QuestionTags': ['azure',
#    'docker',
#    'docker-compose',
#    'azure-web-app-service'],
#   'AnswerOwnerId': 4700678,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56116885,
#   'QuestionTags': ['codeigniter', 'fullcalendar'],
#   'AnswerOwnerId': 6736948,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54829339,
#   'QuestionTags': ['swagger', 'swagger-2.0'],
#   'AnswerOwnerId': 7537885,
#   'transformed_upvotes': 1.9459101490553132},
#  {'QuestionId': 56380971,
#   'QuestionTags': ['css'],
#   'AnswerOwnerId': 2802040,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54697083,
#   'QuestionTags': ['python', 'pandas', 'data-science'],
#   'AnswerOwnerId': 2901002,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54834808,
#   'QuestionTags': ['prestashop', 'prestashop-1.7'],
#   'AnswerOwnerId': 4549054,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55474423,
#   'QuestionTags': ['javascript', 'webpack'],
#   'AnswerOwnerId': 5260024,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 56598804,
#   'QuestionTags': ['python', 'python-3.x', 'pygame'],
#   'AnswerOwnerId': 142637,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 54410689,
#   'QuestionTags': ['php', 'laravel', 'laravel-5.1'],
#   'AnswerOwnerId': 4996862,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56311559,
#   'QuestionTags': ['mysql', 'docker', 'mysql-workbench'],
#   'AnswerOwnerId': 5277922,
#   'transformed_upvotes': -0.6931471805599453},
#  {'QuestionId': 56311559,
#   'QuestionTags': ['mysql', 'docker', 'mysql-workbench'],
#   'AnswerOwnerId': 12710736,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 55180456,
#   'QuestionTags': ['javascript', 'jquery'],
#   'AnswerOwnerId': 5804723,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55180456,
#   'QuestionTags': ['javascript', 'jquery'],
#   'AnswerOwnerId': 8160563,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 54662021,
#   'QuestionTags': ['java', 'apache-flink'],
#   'AnswerOwnerId': 3202696,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54685553,
#   'QuestionTags': ['mediawiki', 'mediawiki-templates'],
#   'AnswerOwnerId': 10908910,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56649872,
#   'QuestionTags': ['scala', 'generics', 'reflection'],
#   'AnswerOwnerId': 5205022,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 55934371,
#   'QuestionTags': ['firebase',
#    'google-cloud-platform',
#    'firebase-realtime-database',
#    'google-cloud-functions',
#    'google-cloud-storage'],
#   'AnswerOwnerId': 3371862,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54286166,
#   'QuestionTags': ['php', 'mysql', 'load-data-infile'],
#   'AnswerOwnerId': 709439,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55504921,
#   'QuestionTags': ['snmp', 'pysnmp', 'mib'],
#   'AnswerOwnerId': 1175029,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55504921,
#   'QuestionTags': ['snmp', 'pysnmp', 'mib'],
#   'AnswerOwnerId': 3648925,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55961868,
#   'QuestionTags': ['javascript', 'html5-canvas', 'timing'],
#   'AnswerOwnerId': 9893154,
#   'transformed_upvotes': -0.6931471805599453},
#  {'QuestionId': 54837439,
#   'QuestionTags': ['javascript'],
#   'AnswerOwnerId': 831878,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54145975,
#   'QuestionTags': ['mysql'],
#   'AnswerOwnerId': 2007837,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54145975,
#   'QuestionTags': ['mysql'],
#   'AnswerOwnerId': 205608,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55236131,
#   'QuestionTags': ['mysql', 'sails.js'],
#   'AnswerOwnerId': 3443618,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54117089,
#   'QuestionTags': ['asp.net',
#    'webpack',
#    'webforms',
#    'webpack-4',
#    'html-webpack-plugin'],
#   'AnswerOwnerId': 10051595,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 54481593,
#   'QuestionTags': ['javascript', 'php', 'jquery', 'html', 'css'],
#   'AnswerOwnerId': 751336,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54481593,
#   'QuestionTags': ['javascript', 'php', 'jquery', 'html', 'css'],
#   'AnswerOwnerId': 1172798,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 54164775,
#   'QuestionTags': ['python'],
#   'AnswerOwnerId': 7023590,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54164775,
#   'QuestionTags': ['python'],
#   'AnswerOwnerId': 7023590,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55253798,
#   'QuestionTags': ['c#', 'xna'],
#   'AnswerOwnerId': 2735344,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55084229,
#   'QuestionTags': ['python', 'curl', 'python-requests'],
#   'AnswerOwnerId': 3629284,
# ...
#   'AnswerOwnerId': 6553328,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56657044,
#   'QuestionTags': ['flutter'],
#   'AnswerOwnerId': 11661407,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 55921916,
#   'QuestionTags': ['javascript', 'openlayers'],
#   'AnswerOwnerId': 7399617,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54006731,
#   'QuestionTags': ['swift', 'image', 'uicollectionview', 'uiactionsheet'],
#   'AnswerOwnerId': 9930790,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55954291,
#   'QuestionTags': ['flutter'],
#   'AnswerOwnerId': 5522344,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56282521,
#   'QuestionTags': ['excel', 'pv'],
#   'AnswerOwnerId': 4332260,
#   'transformed_upvotes': -0.6931471805599453},
#  {'QuestionId': 56282521,
#   'QuestionTags': ['excel', 'pv'],
#   'AnswerOwnerId': 1995735,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55770532,
#   'QuestionTags': ['java', 'arrays'],
#   'AnswerOwnerId': 1140456,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55770532,
#   'QuestionTags': ['java', 'arrays'],
#   'AnswerOwnerId': 11386751,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55770532,
#   'QuestionTags': ['java', 'arrays'],
#   'AnswerOwnerId': 3864917,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55770532,
#   'QuestionTags': ['java', 'arrays'],
#   'AnswerOwnerId': 3141253,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54843872,
#   'QuestionTags': ['javascript',
#    'rest',
#    'validation',
#    'single-page-application'],
#   'AnswerOwnerId': 3084820,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 55675938,
#   'QuestionTags': ['java', 'multithreading'],
#   'AnswerOwnerId': 5344793,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55675938,
#   'QuestionTags': ['java', 'multithreading'],
#   'AnswerOwnerId': 4363390,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56198741,
#   'QuestionTags': ['ruby-on-rails'],
#   'AnswerOwnerId': 154522,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54952470,
#   'QuestionTags': ['python', 'pandas', 'dataframe'],
#   'AnswerOwnerId': 9840637,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 54952470,
#   'QuestionTags': ['python', 'pandas', 'dataframe'],
#   'AnswerOwnerId': 7964527,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 55194645,
#   'QuestionTags': ['python', 'json', 'dictionary', 'utf-8', 'python-2.x'],
#   'AnswerOwnerId': 5320906,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55194645,
#   'QuestionTags': ['python', 'json', 'dictionary', 'utf-8', 'python-2.x'],
#   'AnswerOwnerId': 415016,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55105622,
#   'QuestionTags': ['oracle-database', 'oracle-apex'],
#   'AnswerOwnerId': 527513,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54995959,
#   'QuestionTags': ['python-3.x', 'java-8', 'pyspark'],
#   'AnswerOwnerId': 6301582,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54995959,
#   'QuestionTags': ['python-3.x', 'java-8', 'pyspark'],
#   'AnswerOwnerId': 11017471,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54866783,
#   'QuestionTags': ['spring-kafka'],
#   'AnswerOwnerId': 1240763,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54919270,
#   'QuestionTags': ['json', 'dart', 'flutter', 'json-serialization'],
#   'AnswerOwnerId': 10224869,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54919270,
#   'QuestionTags': ['json', 'dart', 'flutter', 'json-serialization'],
#   'AnswerOwnerId': 2301224,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54919270,
#   'QuestionTags': ['json', 'dart', 'flutter', 'json-serialization'],
#   'AnswerOwnerId': 7638998,
#   'transformed_upvotes': 2.5649493574615367},
#  {'QuestionId': 54919270,
#   'QuestionTags': ['json', 'dart', 'flutter', 'json-serialization'],
#   'AnswerOwnerId': 7837370,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 54919270,
#   'QuestionTags': ['json', 'dart', 'flutter', 'json-serialization'],
#   'AnswerOwnerId': 16025159,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54919270,
#   'QuestionTags': ['json', 'dart', 'flutter', 'json-serialization'],
#   'AnswerOwnerId': 738048,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54919270,
#   'QuestionTags': ['json', 'dart', 'flutter', 'json-serialization'],
#   'AnswerOwnerId': 28207452,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54554527,
#   'QuestionTags': ['wiremock'],
#   'AnswerOwnerId': 2047813,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 56038512,
#   'QuestionTags': ['go', 'file-io', 'file-permissions'],
#   'AnswerOwnerId': 8206,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56038512,
#   'QuestionTags': ['go', 'file-io', 'file-permissions'],
#   'AnswerOwnerId': 200783,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 54937437,
#   'QuestionTags': ['javascript', 'view', 'youtube-data-api'],
#   'AnswerOwnerId': 10753202,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 54937437,
#   'QuestionTags': ['javascript', 'view', 'youtube-data-api'],
#   'AnswerOwnerId': 4464547,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54351562,
#   'QuestionTags': ['awk', 'append', 'match'],
#   'AnswerOwnerId': 5291015,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 54351562,
#   'QuestionTags': ['awk', 'append', 'match'],
#   'AnswerOwnerId': 5403468,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54351562,
#   'QuestionTags': ['awk', 'append', 'match'],
#   'AnswerOwnerId': 1435869,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 54897036,
#   'QuestionTags': ['sql', 'sql-server'],
#   'AnswerOwnerId': 5176071,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54897036,
#   'QuestionTags': ['sql', 'sql-server'],
#   'AnswerOwnerId': 11082033,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54897036,
#   'QuestionTags': ['sql', 'sql-server'],
#   'AnswerOwnerId': 4116017,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56097015,
#   'QuestionTags': ['dart', 'flutter', 'visual-studio-code'],
#   'AnswerOwnerId': 10245598,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56097015,
#   'QuestionTags': ['dart', 'flutter', 'visual-studio-code'],
#   'AnswerOwnerId': 4259748,
#   'transformed_upvotes': -0.6931471805599453},
#  {'QuestionId': 56097015,
#   'QuestionTags': ['dart', 'flutter', 'visual-studio-code'],
#   'AnswerOwnerId': 5046642,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56097015,
#   'QuestionTags': ['dart', 'flutter', 'visual-studio-code'],
#   'AnswerOwnerId': 12764388,
#   'transformed_upvotes': -0.6931471805599453},
#  {'QuestionId': 56097015,
#   'QuestionTags': ['dart', 'flutter', 'visual-studio-code'],
#   'AnswerOwnerId': 2530468,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56097015,
#   'QuestionTags': ['dart', 'flutter', 'visual-studio-code'],
#   'AnswerOwnerId': 13372885,
#   'transformed_upvotes': 1.9459101490553132},
#  {'QuestionId': 56097015,
#   'QuestionTags': ['dart', 'flutter', 'visual-studio-code'],
#   'AnswerOwnerId': 20685883,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56097015,
#   'QuestionTags': ['dart', 'flutter', 'visual-studio-code'],
#   'AnswerOwnerId': 16231131,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56097015,
#   'QuestionTags': ['dart', 'flutter', 'visual-studio-code'],
#   'AnswerOwnerId': 4391518,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56097015,
#   'QuestionTags': ['dart', 'flutter', 'visual-studio-code'],
#   'AnswerOwnerId': 16888056,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55740973,
#   'QuestionTags': ['haskell'],
#   'AnswerOwnerId': 7345298,
#   'transformed_upvotes': 2.6390573296152584},
#  {'QuestionId': 54929491,
#   'QuestionTags': ['json', 'jq'],
#   'AnswerOwnerId': 10248678,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 54929491,
#   'QuestionTags': ['json', 'jq'],
#   'AnswerOwnerId': 3266847,
#   'transformed_upvotes': 1.791759469228055},
#  {'QuestionId': 55146503,
#   'QuestionTags': ['python', 'mysql', 'loops'],
#   'AnswerOwnerId': 2695448,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55146503,
#   'QuestionTags': ['python', 'mysql', 'loops'],
#   'AnswerOwnerId': 10966548,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55701631,
#   'QuestionTags': ['audio', 'google-colaboratory', 'microphone'],
#   'AnswerOwnerId': 8841057,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 55701631,
#   'QuestionTags': ['audio', 'google-colaboratory', 'microphone'],
#   'AnswerOwnerId': 10729292,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56479530,
#   'QuestionTags': ['c++11', 'eigen'],
#   'AnswerOwnerId': 2899559,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 56719846,
#   'QuestionTags': ['javascript', 'css', 'reactjs', 'animation', 'material-ui'],
#   'AnswerOwnerId': 4342108,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55371246,
#   'QuestionTags': ['python-3.x', 'rest', 'powerbi', 'gerrit'],
#   'AnswerOwnerId': 4653675,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56713083,
#   'QuestionTags': ['javascript', 'html', 'arrays', 'regex', 'string'],
#   'AnswerOwnerId': 3874623,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55484665,
#   'QuestionTags': ['php'],
#   'AnswerOwnerId': 5066625,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54262951,
#   'QuestionTags': ['c', 'visual-studio'],
#   'AnswerOwnerId': 235698,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55045792,
#   'QuestionTags': ['javascript', 'css', 'reactjs', 'react-spring'],
#   'AnswerOwnerId': 8120827,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 56220270,
#   'QuestionTags': ['jira', 'itil'],
#   'AnswerOwnerId': 7073449,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56220270,
#   'QuestionTags': ['jira', 'itil'],
#   'AnswerOwnerId': 8330162,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56006762,
#   'QuestionTags': ['python', 'pandas', 'pandas-groupby'],
#   'AnswerOwnerId': 2901002,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 56006762,
#   'QuestionTags': ['python', 'pandas', 'pandas-groupby'],
#   'AnswerOwnerId': 7964527,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56006762,
#   'QuestionTags': ['python', 'pandas', 'pandas-groupby'],
#   'AnswerOwnerId': 4238408,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54976067,
#   'QuestionTags': ['cassandra',
#    'cql',
#    'cassandra-2.0',
#    'cassandra-3.0',
#    'cqlsh'],
#   'AnswerOwnerId': 4940826,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 54563013,
#   'QuestionTags': ['unity-game-engine'],
#   'AnswerOwnerId': 81306,
#   'transformed_upvotes': 2.0794415416798357},
#  {'QuestionId': 54563013,
#   'QuestionTags': ['unity-game-engine'],
#   'AnswerOwnerId': 10875792,
#   'transformed_upvotes': 2.0794415416798357},
#  {'QuestionId': 54563013,
#   'QuestionTags': ['unity-game-engine'],
#   'AnswerOwnerId': 975638,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54563013,
#   'QuestionTags': ['unity-game-engine'],
#   'AnswerOwnerId': 843876,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54672109,
#   'QuestionTags': ['python',
#    'machine-learning',
#    'scikit-learn',
#    'missing-data'],
#   'AnswerOwnerId': 5331696,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54672109,
#   'QuestionTags': ['python',
#    'machine-learning',
#    'scikit-learn',
#    'missing-data'],
#   'AnswerOwnerId': 676634,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55622078,
#   'QuestionTags': ['c++', 'typedef'],
#   'AnswerOwnerId': 6266,
#   'transformed_upvotes': 1.6094379124341003},
#  {'QuestionId': 55622078,
#   'QuestionTags': ['c++', 'typedef'],
#   'AnswerOwnerId': 7757891,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55622078,
#   'QuestionTags': ['c++', 'typedef'],
#   'AnswerOwnerId': 4967403,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 55518386,
#   'QuestionTags': ['powershell'],
#   'AnswerOwnerId': 11025476,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 54518807,
#   'QuestionTags': ['command-line-interface',
#    'openshift',
#    'openshift-origin',
#    'okd'],
#   'AnswerOwnerId': 6758654,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 55738344,
#   'QuestionTags': ['javascript', 'jquery'],
#   'AnswerOwnerId': 4551487,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56787101,
#   'QuestionTags': ['java',
#    'selenium',
#    'selenium-webdriver',
#    'local',
#    'browserstack'],
#   'AnswerOwnerId': 8604933,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56579694,
#   'QuestionTags': ['github'],
#   'AnswerOwnerId': 10445225,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54403133,
#   'QuestionTags': ['elasticsearch', 'lucene', 'hibernate-search'],
#   'AnswerOwnerId': 2379083,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55237718,
#   'QuestionTags': ['git', 'version-control'],
#   'AnswerOwnerId': 7050130,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54864374,
#   'QuestionTags': ['javascript', 'jquery', 'datatables', 'datatables-1.10'],
#   'AnswerOwnerId': 3231537,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54864374,
#   'QuestionTags': ['javascript', 'jquery', 'datatables', 'datatables-1.10'],
#   'AnswerOwnerId': 3864917,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56815148,
#   'QuestionTags': ['ionic4', 'alexa-skills-kit', 'alexa-voice-service'],
#   'AnswerOwnerId': 156388,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 56815148,
#   'QuestionTags': ['ionic4', 'alexa-skills-kit', 'alexa-voice-service'],
#   'AnswerOwnerId': 6353959,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55737975,
#   'QuestionTags': ['java', 'jms', 'ibm-mq'],
#   'AnswerOwnerId': 4042083,
#   'transformed_upvotes': 1.3862943611198906},
#  {'QuestionId': 54260244,
#   'QuestionTags': ['python', 'scrapy'],
#   'AnswerOwnerId': 10832127,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54260244,
#   'QuestionTags': ['python', 'scrapy'],
#   'AnswerOwnerId': 939364,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56544823,
#   'QuestionTags': ['python-3.x', 'types', 'mypy'],
#   'AnswerOwnerId': 646543,
#   'transformed_upvotes': 2.0794415416798357},
#  {'QuestionId': 56327780,
#   'QuestionTags': ['internet-explorer-11', 'jaws-screen-reader'],
#   'AnswerOwnerId': 1910459,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54047767,
#   'QuestionTags': ['mysql', 'sql', 'format', 'workbench'],
#   'AnswerOwnerId': 4712613,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55939446,
#   'QuestionTags': ['sql-delete', 'cloudkit'],
#   'AnswerOwnerId': 7965564,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56352932,
#   'QuestionTags': ['javascript', 'reactjs', 'typescript'],
#   'AnswerOwnerId': 390330,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 56352932,
#   'QuestionTags': ['javascript', 'reactjs', 'typescript'],
#   'AnswerOwnerId': 10679524,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 54092481,
#   'QuestionTags': ['javascript', 'integer', 'long-integer'],
#   'AnswerOwnerId': 978690,
#   'transformed_upvotes': 1.0986122886681098},
#  {'QuestionId': 55476716,
#   'QuestionTags': ['java', 'sqlite', 'gradle'],
#   'AnswerOwnerId': 3485876,
#   'transformed_upvotes': 1.9459101490553132},
#  {'QuestionId': 55476716,
#   'QuestionTags': ['java', 'sqlite', 'gradle'],
#   'AnswerOwnerId': 27272539,
#   'transformed_upvotes': 0.6931471805599453},
#  {'QuestionId': 55977473,
#   'QuestionTags': ['c#', 'file', 'search'],
#   'AnswerOwnerId': 880990,
#   'transformed_upvotes': 1.0986122886681098},
#  ...]

# %% [markdown]
# ### Creating User-Tag Matrix

# %%
# Step 1: Create the Frequency Matrix (count occurrences)
rows_freq, cols_freq, data_freq = [], [], []
rows_upvote, cols_upvote, data_upvote = [], [], []

for question in dic_merged:
    user_idx = user_to_index[question['AnswerOwnerId']]
    for tag in question['QuestionTags']:
        tag_idx = tag_to_index[tag]
        
        # Frequency: Count interactions
        rows_freq.append(user_idx)
        cols_freq.append(tag_idx)
        data_freq.append(1)
        
        # Upvote: Sum upvotes
        upvotes = question['transformed_upvotes']
        if isinstance(upvotes, (int, float)):
            rows_upvote.append(user_idx)
            cols_upvote.append(tag_idx)
            data_upvote.append(upvotes)

# Step 2: Construct the matrices
frequency_matrix = csr_matrix((data_freq, (rows_freq, cols_freq)), shape=(len(unique_users), len(unique_tags)))
upvote_matrix = csr_matrix((data_upvote, (rows_upvote, cols_upvote)), shape=(len(unique_users), len(unique_tags)))

# Step 3: Compute the weighted matrix by element-wise multiplication
user_tag_matrix_sparse = frequency_matrix.multiply(upvote_matrix)

# Optional: Convert to a dense matrix to inspect the result (only if it's small)
# print(weighted_matrix.todense())

# %% [markdown]
# ### Calculating Tags Similarity Matrix

# %%
# Compute Tag Similarity
cos_sim_matrix = cosine_similarity(user_tag_matrix_sparse.T)

# %% [markdown]
# ### Recommending User

# %%
## Example to 1 question
# tags = test_data["QuestionTags"].iloc[0]
# tags

tags = ["r", "radar-chart", "spider-chart"]

# %%
def recommend_users_collaborative(tags, top_n=10):
    # Get indices of the tags
    tag_indices = [tag_to_index[tag] for tag in tags if tag in tag_to_index]
    if len(tag_indices)==0:
        return [] ## No tag found to make the suggestion
    
    # Combine similarities for the requested tags
    similarity_tags = [cos_sim_matrix[:, tag_index] for tag_index in tag_indices]
    combined_similarity = sum(similarity_tags)

    # Compute user scores 
    user_scores_vector = user_tag_matrix_sparse.dot(combined_similarity)

    # Map scores to users
    user_scores = {unique_users[idx]: score for idx, score in enumerate(user_scores_vector)}

    # Rank users by scores
    ranked_users = sorted(user_scores.items(), key=lambda x: x[1], reverse=True)
    # return ranked_users[:top_n]
    return ranked_users

# %%
return_1 = recommend_users_collaborative(tags)

# %% [markdown]
# ## Prototype 2 - Approach Content Based-Filtering
#
#
# - **Goal:** Find answerers to new posted question.
#
# - **Approach:** Content Based-Filtering --> Utilize question tags of previous answered questions, to indicate the most appropriate user.
#
# - **Steps:**
#
# 1. Create Matrix of User-Tags
# 2. Create vector of to the new tag based on the Matrix of User-tags
# 3. Calculate cosine similarity for each user with vector created in step 2
# 4. Order list to show the most recommended users

# %%
# We are going start using some User-Tag matrix of the previous approach

def recommend_users_content(tags, top_n=10):
    # Get index of the tags
    tag_indices = [tag_to_index[tag] for tag in tags if tag in tag_to_index]
    if len(tag_indices)==0:
        return [] ## No tag found to make the suggestion
            
    # Create vector of the tags in question
    question_vector = np.zeros(user_tag_matrix_sparse.shape[1])
    question_vector[tag_indices] = 1
    question_vector= question_vector.reshape(1, -1) #Reshaping array to calculate similarity

    user_scores_vector = cosine_similarity(user_tag_matrix_sparse, question_vector)
    user_scores_vector = user_scores_vector.flatten()

    # Map scores to users
    user_scores = {unique_users[idx]: score for idx, score in enumerate(user_scores_vector)}

    # Rank users by scores
    ranked_users = sorted(user_scores.items(), key=lambda x: x[1], reverse=True)
    # return ranked_users[:10]
    return ranked_users

# %%
return_2 = recommend_users_content(tags)

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Top-N Accuracy

# %%
df_merged_test = test_data[["QuestionId","QuestionTags"]].merge(df_answer[["QuestionId", "AnswerOwnerId"]], how='inner', on = "QuestionId", )

# %% [markdown]
# Joining the Users to form a single ground truth

# %%
# Convert QuestionTags from lists to tuples
df_merged_test["QuestionTags"] = df_merged_test["QuestionTags"].apply(tuple)

# Group AnswerOwnerId by QuestionId and QuestionTags
grouped_df = (
    df_merged_test.groupby(["QuestionId", "QuestionTags"])["AnswerOwnerId"]
    .apply(list)  # Combine AnswerOwnerId values into a list
    .reset_index()
    .rename(columns={"AnswerOwnerId": "GroundTruth"})
)

# %%
ground_truth_dic = grouped_df.to_dict(orient='records')

# %% [markdown]
# Calculate the results for all questions

# %%
import threading
from functools import lru_cache

# Cached recommendation function wrapper
@lru_cache(maxsize=len(ground_truth_dic))
def cached_recommendation(tags, recommendation_function, top_n):
    return recommendation_function(tuple(tags))[:top_n]

# Threaded version of the evaluation process with caching
def threaded_top_n_accuracy_with_cache(ground_truth_dic, recommendation_function, top_n=5):
    def evaluate_question(question, result, index):
        # Get recommendations using cached function
        top_users = cached_recommendation(tuple(question["QuestionTags"]), recommendation_function, top_n)
        top_users_list = [user[0] for user in top_users]
        
        # Check for overlap with ground truth
        users_groundtruth = question["GroundTruth"]
        result[index] = int(bool(set(top_users_list) & set(users_groundtruth)))

    # Shared list to store results
    results = [0] * len(ground_truth_dic)
    threads = []

    # Create and start threads
    for idx, question in enumerate(ground_truth_dic):
        thread = threading.Thread(target=evaluate_question, args=(question, results, idx))
        threads.append(thread)
        thread.start()

    # Wait for all threads to complete
    for thread in threads:
        thread.join()
        

    # Calculate accuracy
    return sum(results) / len(ground_truth_dic)

# %% [markdown]
# Collaborative

# %%
top_n = [10, 20, 50, 100]
results = []

for top in top_n:
    result = {
        "acc": threaded_top_n_accuracy_with_cache(ground_truth_dic[:100], recommend_users_collaborative, top),
        "top": top,
        "type": "collaborative"
    }
    
    print(result)
    results.append(result)
# Out:
# {'acc': 0.1, 'top': 10, 'type': 'collaborative'}
# {'acc': 0.14, 'top': 20, 'type': 'collaborative'}
# {'acc': 0.19, 'top': 50, 'type': 'collaborative'}
# {'acc': 0.3, 'top': 100, 'type': 'collaborative'}

# %% [markdown]
# Content

# %%
# Clean cache
cached_recommendation.cache_clear()
for top in top_n:
    result = {
        "acc": threaded_top_n_accuracy_with_cache(ground_truth_dic[:100], recommend_users_content, top),
        "top": top,
        "type": "content"
    }
    print(result)
    results.append(result)
# Out:
# {'acc': 0.05, 'top': 10, 'type': 'content'}
# {'acc': 0.06, 'top': 20, 'type': 'content'}
# {'acc': 0.13, 'top': 50, 'type': 'content'}

# %%
pd.DataFrame(results).to_csv("prototype_v1.csv", index=False)
